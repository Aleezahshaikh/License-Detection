# %% [markdown]
# <a href="https://colab.research.google.com/github/Aleezahshaikh/License-Detection/blob/main/Licence_Plate_Recognition_YOLOV8_EasyOCR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR
# Out:
# /content/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR

# %%
pip install -r requirements.txt

# %%
# !pip uninstall -y ultralytics
# !pip install ultralytics==8.3.112
# Out:
# Found existing installation: ultralytics 8.3.112
# Uninstalling ultralytics-8.3.112:
#   Successfully uninstalled ultralytics-8.3.112
# ...
#   Using cached ultralytics-8.3.112-py3-none-any.whl.metadata (37 kB)
# ...
# Using cached ultralytics-8.3.112-py3-none-any.whl (981 kB)
# ...

# %%
import ultralytics
print(ultralytics.__version__)  # Should print 8.3.112
# Out:
# 8.3.112

# %%
rm -rf /content/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR/ultralytics

# %%
# !python predictWithOCR.py /content/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR/best.pt /content/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR/demo.mp4
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
#
# 0: 416x640 1 LicensePlate, 257.7ms
# Speed: 6.1ms preprocess, 257.7ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 234.8ms
# Speed: 4.9ms preprocess, 234.8ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 229.8ms
# Speed: 4.6ms preprocess, 229.8ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 226.6ms
# Speed: 5.8ms preprocess, 226.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 196.4ms
# Speed: 4.8ms preprocess, 196.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 142.5ms
# Speed: 4.7ms preprocess, 142.5ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 LicensePlate, 140.3ms
# ...

# %%
# !python predictWithOCR.py /content/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR/best.pt /content/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR/testcar.jpg
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
#
# image 1/1 /content/Licence-Plate-Detection-and-Recognition-using-YOLO-V8-EasyOCR/testcar.jpg: 448x640 1 LicensePlate, 170.5ms
# Speed: 3.4ms preprocess, 170.5ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
# Result image saved as: inference_output/result.jpg
